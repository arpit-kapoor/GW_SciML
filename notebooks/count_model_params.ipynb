# %%
import numpy as np
import pickle
import torch

# %%
checkpoint_path = '/scratch/yl75/ak4177/results/groundwater/GINO/standard/training_20260715_181457/checkpoints/latest_checkpoint.pth'
saved_model = torch.load(checkpoint_path, map_location=torch.device('cpu'), weights_only=False)

# %%
state_dict = saved_model['model_state_dict']
total_elements = sum(p.numel() for p in state_dict.values())
print(f"Total elements in state_dict: {total_elements}")
# Out:
# Total elements in state_dict: 33701008
